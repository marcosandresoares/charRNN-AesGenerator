# %%
import numpy as np
import torch
from torch import nn
import torch.nn.functional as F
from torch.autograd import Variable

# %%
path = 'data_album/aesop_rock.txt'
text = open(path).read().lower()

print('Corpus length: {}'.format(len(text)))
# Out:
# Corpus length: 271935

# %%
chars = sorted(list(set(text)))
print ('Total Characters: {}'.format(len(chars)))
# Out:
# Total Characters: 65

# %%
with open('data_album/aesop_rock.txt', 'r') as f:
    text = f.read()

# %%
chars = tuple(set(text))
int_to_char = dict(enumerate(chars))
char_to_int = {character : index for index, character in int_to_char.items()}
encoded = np.array([char_to_int[character] for character in text])

# %% [markdown]
# ## Preprocessing the Data

# %%
def one_hot_encode(arr, n_labels):
    
    # initialize the encoded array
    one_hot = np.zeros((np.multiply(*arr.shape), n_labels), dtype = np.float32)
    
    # Fill the appropriate elements with ones
    one_hot[np.arange(one_hot.shape[0]), arr.flatten()] = 1
    
    # reshape it to get back to the original array
    one_hot = one_hot.reshape((*arr.shape, n_labels))
    
    return one_hot

# %%
def get_batches(arr, n_seqs, n_steps):
    '''
    Create a generator that returns mini-batches
    of size n_seqs x n_steps from arr
    '''
    
    batch_size = n_seqs * n_steps
    n_batches = len(arr)//batch_size
    
    # keep only enough characters to make full batches
    arr = arr[:n_batches*batch_size]
    # reshape into n_seqs rows
    arr = arr.reshape((n_seqs, -1))
    
    for n in range(0, arr.shape[1], n_steps):
        # the features
        x = arr[:, n:n+n_steps]
        # the targets, shifted by one
        y = np.zeros_like(x)
        try:
            y[:, :-1], y[:, -1] = x[:, 1:], arr[:, n+n_steps]
        except IndexError:
            y[:, :-1], y[:, -1] = x[:, 1:], arr[:, 0]
        yield x, y

# %% [markdown]
# ## Define network with PyTorch

# %%
class CharRNN(nn.Module):
    def __init__(self, 
                 tokens, 
                 n_steps = 100, 
                 n_hidden = 256, 
                 n_layers = 2, 
                 drop_prob = 0.5, 
                 lr = 0.001):
        super().__init__()
        self.n_hidden = n_hidden
        self.n_layers = n_layers
        self.drop_prob = drop_prob
        self.lr = lr
        
        self.chars = tokens
        self.int_to_char = dict(enumerate(self.chars))
        self.char_to_int = {character:index for index, character in self.int_to_char.items()}
        
        self.dropout = nn.Dropout(drop_prob)
        self.lstm = nn.LSTM(len(self.chars),
                           n_hidden,
                           n_layers,
                           dropout = drop_prob,
                           batch_first = True)
        self.fc = nn.Linear(n_hidden,
                           len(self.chars))
        
        self.init_weights()
        
    def forward(self,
               x,
               hc):
        '''
        Forward pass through the network
        '''
        
        x,(h,c) = self.lstm(x,hc)
        x = self.dropout(x)
        
        # stack up LSTM outputs
        x = x.view(x.size()[0] * x.size()[1],
                  self.n_hidden)
        
        x = self.fc(x)
        
        return x, (h,c)
        
    def predict(self,
               char,
               h = None,
               cuda = False,
               top_k = None):
        '''
        Given a character, predict the next character
        Returns the predicted character and the hidden state
        '''
        if cuda:
            self.cuda()
        else:
            self.cpu()
        
        if h is None:
            h = self.init_hidden(1)
        
        x = np.array([[self.char_to_int[char]]])
        x = one_hot_encode(x, len(self.chars))
        inputs = Variable(torch.from_numpy(x),
                         volatile = True)
        if cuda:
            inputs = inputs.cuda()
        
        h = tuple([Variable(each.data, volatile = True) for each in h])
        out, h = self.forward(inputs, h)
        
        p = F.softmax(out).data
        if cuda:
            p = p.cpu()
        
        if top_k is None:
            top_ch = np.arange(len(self.chars))
        else:
            p, top_ch = p.topk(top_k)
            top_ch = top_ch.numpy().squeeze()
        
        p = p.numpy().squeeze()
        char = np.random.choice(top_ch, p = p/p.sum())
        
        return self.int_to_char[char], h
        
    
    def init_weights(self):
        '''
        Initialize weights for fully connected layer
        '''
        initrange = 0.1
        
        # set bias tensor to all zeros
        self.fc.bias.data.fill_(0)
        
        # FC weights as random uniform
        self.fc.weight.data.uniform_(-1,1)
        
    def init_hidden(self,
                   n_seqs):
        '''
        Initialize hidden state
        '''
        # Create two new tensors with sizes n_layers x n_seqs x n_hidden,
        # initialized to zero, for hidden state and cell state of LSTM
        weight = next(self.parameters()).data
        return (Variable(weight.new(self.n_layers, n_seqs, self.n_hidden).zero_()),
                Variable(weight.new(self.n_layers, n_seqs, self.n_hidden).zero_()))

# %%
def train(net,
         data,
         epochs = 10,
         n_seqs = 10,
         n_steps = 50,
         lr = 0.001,
         clip = 5,
         val_frac = 0.1,
         cuda = False,
         print_every = 10):
    
    net.train()
    opt = torch.optim.Adam(net.parameters(), lr = lr)
    criterion = nn.CrossEntropyLoss()
    
    # create training and validation data
    val_index = int(len(data)*(1-val_frac))
    data, val_data = data[:val_index], data[val_index:]
    
    if cuda:
        net.cuda()
    
    counter = 0
    n_characters = len(net.chars)
    for epoch in range(epochs):
        h = net.init_hidden(n_seqs)
        for x, y in get_batches(data, n_seqs, n_steps):
            counter += 1
            
            # One hot encode our data and make them Torch tensors
            x = one_hot_encode(x, n_characters)
            x, y = torch.from_numpy(x), torch.from_numpy(y)
            
            inputs, targets = Variable(x), Variable(y)
            if cuda:
                inputs, targets = inputs.cuda(), targets.cuda()
            
            # Create new variables for the hidden state
            # otherwise, we'd backprop through the entire training history
            h = tuple([Variable(each.data) for each in h])
            
            net.zero_grad()
            
            output, h = net.forward(inputs, h)
            loss = criterion(output, targets.view(n_seqs*n_steps))
            
            loss.backward()
            
            # clip_grad_norm helps prevent the explodng gradient problem in RNNs
            nn.utils.clip_grad_norm(net.parameters(),clip)
            
            opt.step()
            
            if counter % print_every == 0:
                # Get validation loss
                val_h = net.init_hidden(n_seqs)
                val_losses = []
                for x, y in get_batches(val_data, n_seqs, n_steps):
                    x = one_hot_encode(x, n_characters)
                    x, y = torch.from_numpy(x), torch.from_numpy(y)
                    
                    val_h = tuple([Variable(each.data, volatile = True) for each in val_h])
                    
                    inputs, targets = Variable(x, volatile = True), Variable(y, volatile = True)
                    if cuda:
                        inputs, targets = inputs.cuda(), targets.cuda()
                    
                    output, val_h = net.forward(inputs, val_h)
                    val_loss = criterion(output, targets.view(n_seqs*n_steps))
                    
                    val_losses.append(val_loss.data[0])
                    
                print('====================',
                      'Epoch: {}/{} ...'.format(epoch+1, epochs),
                      'Step: {}...'.format(counter),
                      'Loss: {:.4f}...'.format(loss.data[0]),
                      'Validation Loss: {:.4f}...'.format(np.mean(val_losses)),
                      '====================')

# %% [markdown]
# ## Train the network

# %%
if 'net' in locals():
    del net

# %%
net = CharRNN(chars,
             n_hidden = 512,
             n_layers = 2)

# %%
epochs = 50
n_seqs = 128
n_steps = 100
lr = 0.001
print_every_2 = 2

train(net,
     encoded,
     epochs,
     n_seqs,
     n_steps,
     lr,
     cuda = False, # CUDA support
     print_every = print_every_2)
# Out:
# ==================== Epoch: 1/50 ... Step: 2... Loss: 4.0655... Validation Loss: 3.7691... ====================
# ==================== Epoch: 1/50 ... Step: 4... Loss: 3.5589... Validation Loss: 3.5592... ====================
# ==================== Epoch: 1/50 ... Step: 6... Loss: 3.4432... Validation Loss: 3.4523... ====================
# ==================== Epoch: 1/50 ... Step: 8... Loss: 3.4159... Validation Loss: 3.4135... ====================
# ==================== Epoch: 1/50 ... Step: 10... Loss: 3.3863... Validation Loss: 3.3805... ====================
# ==================== Epoch: 1/50 ... Step: 12... Loss: 3.3309... Validation Loss: 3.3604... ====================
# ==================== Epoch: 1/50 ... Step: 14... Loss: 3.3353... Validation Loss: 3.3327... ====================
# ==================== Epoch: 1/50 ... Step: 16... Loss: 3.3038... Validation Loss: 3.3171... ====================
# ==================== Epoch: 1/50 ... Step: 18... Loss: 3.2880... Validation Loss: 3.2957... ====================
# ==================== Epoch: 2/50 ... Step: 20... Loss: 3.2784... Validation Loss: 3.2808... ====================
# ==================== Epoch: 2/50 ... Step: 22... Loss: 3.2567... Validation Loss: 3.2605... ====================
# ==================== Epoch: 2/50 ... Step: 24... Loss: 3.2449... Validation Loss: 3.2407... ====================
# ==================== Epoch: 2/50 ... Step: 26... Loss: 3.2098... Validation Loss: 3.2218... ====================
# ==================== Epoch: 2/50 ... Step: 28... Loss: 3.1953... Validation Loss: 3.2003... ====================
# ==================== Epoch: 2/50 ... Step: 30... Loss: 3.1691... Validation Loss: 3.1729... ====================
# ==================== Epoch: 2/50 ... Step: 32... Loss: 3.1714... Validation Loss: 3.1502... ====================
# ==================== Epoch: 2/50 ... Step: 34... Loss: 3.1484... Validation Loss: 3.1332... ====================
# ==================== Epoch: 2/50 ... Step: 36... Loss: 3.1047... Validation Loss: 3.0983... ====================
# ==================== Epoch: 2/50 ... Step: 38... Loss: 3.0985... Validation Loss: 3.0783... ====================
# ==================== Epoch: 3/50 ... Step: 40... Loss: 3.0619... Validation Loss: 3.0548... ====================
# ==================== Epoch: 3/50 ... Step: 42... Loss: 3.0405... Validation Loss: 3.0176... ====================
# ==================== Epoch: 3/50 ... Step: 44... Loss: 2.9949... Validation Loss: 2.9916... ====================
# ==================== Epoch: 3/50 ... Step: 46... Loss: 2.9726... Validation Loss: 2.9553... ====================
# ==================== Epoch: 3/50 ... Step: 48... Loss: 2.9456... Validation Loss: 2.9321... ====================
# ==================== Epoch: 3/50 ... Step: 50... Loss: 2.8901... Validation Loss: 2.8925... ====================
# ==================== Epoch: 3/50 ... Step: 52... Loss: 2.8762... Validation Loss: 2.8649... ====================
# ==================== Epoch: 3/50 ... Step: 54... Loss: 2.8335... Validation Loss: 2.8326... ====================
# ==================== Epoch: 3/50 ... Step: 56... Loss: 2.8205... Validation Loss: 2.8206... ====================
# ==================== Epoch: 4/50 ... Step: 58... Loss: 2.8249... Validation Loss: 2.8025... ====================
# ==================== Epoch: 4/50 ... Step: 60... Loss: 2.7792... Validation Loss: 2.7774... ====================
# ==================== Epoch: 4/50 ... Step: 62... Loss: 2.7833... Validation Loss: 2.7525... ====================
# ==================== Epoch: 4/50 ... Step: 64... Loss: 2.7145... Validation Loss: 2.7349... ====================
# ==================== Epoch: 4/50 ... Step: 66... Loss: 2.7139... Validation Loss: 2.7244... ====================
# ==================== Epoch: 4/50 ... Step: 68... Loss: 2.7287... Validation Loss: 2.7054... ====================
# ==================== Epoch: 4/50 ... Step: 70... Loss: 2.7251... Validation Loss: 2.6858... ====================
# ==================== Epoch: 4/50 ... Step: 72... Loss: 2.6921... Validation Loss: 2.6740... ====================
# ==================== Epoch: 4/50 ... Step: 74... Loss: 2.6615... Validation Loss: 2.6625... ====================
# ==================== Epoch: 4/50 ... Step: 76... Loss: 2.6776... Validation Loss: 2.6478... ====================
# ==================== Epoch: 5/50 ... Step: 78... Loss: 2.6620... Validation Loss: 2.6362... ====================
# ==================== Epoch: 5/50 ... Step: 80... Loss: 2.6377... Validation Loss: 2.6257... ====================
# ==================== Epoch: 5/50 ... Step: 82... Loss: 2.6184... Validation Loss: 2.6117... ====================
# ==================== Epoch: 5/50 ... Step: 84... Loss: 2.5973... Validation Loss: 2.6055... ====================
# ==================== Epoch: 5/50 ... Step: 86... Loss: 2.5831... Validation Loss: 2.5906... ====================
# ==================== Epoch: 5/50 ... Step: 88... Loss: 2.5686... Validation Loss: 2.5916... ====================
# ==================== Epoch: 5/50 ... Step: 90... Loss: 2.5649... Validation Loss: 2.5667... ====================
# ==================== Epoch: 5/50 ... Step: 92... Loss: 2.5533... Validation Loss: 2.5677... ====================
# ==================== Epoch: 5/50 ... Step: 94... Loss: 2.5666... Validation Loss: 2.5566... ====================
# ==================== Epoch: 6/50 ... Step: 96... Loss: 2.5606... Validation Loss: 2.5588... ====================
# ==================== Epoch: 6/50 ... Step: 98... Loss: 2.5561... Validation Loss: 2.5443... ====================
# ==================== Epoch: 6/50 ... Step: 100... Loss: 2.5455... Validation Loss: 2.5378... ====================
# ==================== Epoch: 6/50 ... Step: 102... Loss: 2.5024... Validation Loss: 2.5303... ====================
# ==================== Epoch: 6/50 ... Step: 104... Loss: 2.5019... Validation Loss: 2.5219... ====================
# ==================== Epoch: 6/50 ... Step: 106... Loss: 2.5168... Validation Loss: 2.5209... ====================
# ==================== Epoch: 6/50 ... Step: 108... Loss: 2.5305... Validation Loss: 2.5162... ====================
# ==================== Epoch: 6/50 ... Step: 110... Loss: 2.5133... Validation Loss: 2.5037... ====================
# ==================== Epoch: 6/50 ... Step: 112... Loss: 2.4867... Validation Loss: 2.4956... ====================
# ==================== Epoch: 6/50 ... Step: 114... Loss: 2.5038... Validation Loss: 2.4919... ====================
# ==================== Epoch: 7/50 ... Step: 116... Loss: 2.5042... Validation Loss: 2.4850... ====================
# ==================== Epoch: 7/50 ... Step: 118... Loss: 2.4855... Validation Loss: 2.4827... ====================
# ==================== Epoch: 7/50 ... Step: 120... Loss: 2.4808... Validation Loss: 2.4754... ====================
# ==================== Epoch: 7/50 ... Step: 122... Loss: 2.4746... Validation Loss: 2.4727... ====================
# ==================== Epoch: 7/50 ... Step: 124... Loss: 2.4608... Validation Loss: 2.4671... ====================
# ==================== Epoch: 7/50 ... Step: 126... Loss: 2.4462... Validation Loss: 2.4652... ====================
# ==================== Epoch: 7/50 ... Step: 128... Loss: 2.4474... Validation Loss: 2.4557... ====================
# ==================== Epoch: 7/50 ... Step: 130... Loss: 2.4425... Validation Loss: 2.4478... ====================
# ==================== Epoch: 7/50 ... Step: 132... Loss: 2.4347... Validation Loss: 2.4489... ====================
# ==================== Epoch: 8/50 ... Step: 134... Loss: 2.4595... Validation Loss: 2.4419... ====================
# ==================== Epoch: 8/50 ... Step: 136... Loss: 2.4460... Validation Loss: 2.4383... ====================
# ==================== Epoch: 8/50 ... Step: 138... Loss: 2.4284... Validation Loss: 2.4373... ====================
# ==================== Epoch: 8/50 ... Step: 140... Loss: 2.3984... Validation Loss: 2.4305... ====================
# ==================== Epoch: 8/50 ... Step: 142... Loss: 2.4077... Validation Loss: 2.4220... ====================
# ==================== Epoch: 8/50 ... Step: 144... Loss: 2.4252... Validation Loss: 2.4287... ====================
# ==================== Epoch: 8/50 ... Step: 146... Loss: 2.4351... Validation Loss: 2.4144... ====================
# ==================== Epoch: 8/50 ... Step: 148... Loss: 2.4157... Validation Loss: 2.4129... ====================
# ==================== Epoch: 8/50 ... Step: 150... Loss: 2.4012... Validation Loss: 2.4048... ====================
# ==================== Epoch: 8/50 ... Step: 152... Loss: 2.4165... Validation Loss: 2.4116... ====================
# ==================== Epoch: 9/50 ... Step: 154... Loss: 2.4156... Validation Loss: 2.3978... ====================
# ==================== Epoch: 9/50 ... Step: 156... Loss: 2.4013... Validation Loss: 2.3999... ====================
# ==================== Epoch: 9/50 ... Step: 158... Loss: 2.3892... Validation Loss: 2.3917... ====================
# ==================== Epoch: 9/50 ... Step: 160... Loss: 2.3779... Validation Loss: 2.3888... ====================
# ==================== Epoch: 9/50 ... Step: 162... Loss: 2.3741... Validation Loss: 2.3879... ====================
# ==================== Epoch: 9/50 ... Step: 164... Loss: 2.3607... Validation Loss: 2.3827... ====================
# ==================== Epoch: 9/50 ... Step: 166... Loss: 2.3653... Validation Loss: 2.3784... ====================
# ==================== Epoch: 9/50 ... Step: 168... Loss: 2.3599... Validation Loss: 2.3822... ====================
# ==================== Epoch: 9/50 ... Step: 170... Loss: 2.3512... Validation Loss: 2.3810... ====================
# ==================== Epoch: 10/50 ... Step: 172... Loss: 2.3884... Validation Loss: 2.3706... ====================
# ==================== Epoch: 10/50 ... Step: 174... Loss: 2.3721... Validation Loss: 2.3655... ====================
# ==================== Epoch: 10/50 ... Step: 176... Loss: 2.3485... Validation Loss: 2.3666... ====================
# ==================== Epoch: 10/50 ... Step: 178... Loss: 2.3316... Validation Loss: 2.3627... ====================
# ==================== Epoch: 10/50 ... Step: 180... Loss: 2.3357... Validation Loss: 2.3511... ====================
# ==================== Epoch: 10/50 ... Step: 182... Loss: 2.3641... Validation Loss: 2.3566... ====================
# ==================== Epoch: 10/50 ... Step: 184... Loss: 2.3648... Validation Loss: 2.3510... ====================
# ==================== Epoch: 10/50 ... Step: 186... Loss: 2.3425... Validation Loss: 2.3469... ====================
# ==================== Epoch: 10/50 ... Step: 188... Loss: 2.3111... Validation Loss: 2.3442... ====================
# ==================== Epoch: 10/50 ... Step: 190... Loss: 2.3577... Validation Loss: 2.3463... ====================
# ==================== Epoch: 11/50 ... Step: 192... Loss: 2.3530... Validation Loss: 2.3399... ====================
# ==================== Epoch: 11/50 ... Step: 194... Loss: 2.3375... Validation Loss: 2.3363... ====================
# ==================== Epoch: 11/50 ... Step: 196... Loss: 2.3304... Validation Loss: 2.3364... ====================
# ==================== Epoch: 11/50 ... Step: 198... Loss: 2.3150... Validation Loss: 2.3341... ====================
# ==================== Epoch: 11/50 ... Step: 200... Loss: 2.3012... Validation Loss: 2.3261... ====================
# ==================== Epoch: 11/50 ... Step: 202... Loss: 2.2994... Validation Loss: 2.3183... ====================
# ==================== Epoch: 11/50 ... Step: 204... Loss: 2.2972... Validation Loss: 2.3185... ====================
# ==================== Epoch: 11/50 ... Step: 206... Loss: 2.2969... Validation Loss: 2.3148... ====================
# ==================== Epoch: 11/50 ... Step: 208... Loss: 2.2967... Validation Loss: 2.3161... ====================
# ==================== Epoch: 12/50 ... Step: 210... Loss: 2.3221... Validation Loss: 2.3197... ====================
# ==================== Epoch: 12/50 ... Step: 212... Loss: 2.3063... Validation Loss: 2.3131... ====================
# ==================== Epoch: 12/50 ... Step: 214... Loss: 2.2920... Validation Loss: 2.3076... ====================
# ==================== Epoch: 12/50 ... Step: 216... Loss: 2.2718... Validation Loss: 2.3015... ====================
# ==================== Epoch: 12/50 ... Step: 218... Loss: 2.2698... Validation Loss: 2.3102... ====================
# ==================== Epoch: 12/50 ... Step: 220... Loss: 2.2971... Validation Loss: 2.3029... ====================
# ==================== Epoch: 12/50 ... Step: 222... Loss: 2.3007... Validation Loss: 2.3011... ====================
# ==================== Epoch: 12/50 ... Step: 224... Loss: 2.2970... Validation Loss: 2.2975... ====================
# ==================== Epoch: 12/50 ... Step: 226... Loss: 2.2659... Validation Loss: 2.2920... ====================
# ==================== Epoch: 12/50 ... Step: 228... Loss: 2.3044... Validation Loss: 2.3041... ====================
# ==================== Epoch: 13/50 ... Step: 230... Loss: 2.3204... Validation Loss: 2.2982... ====================
# ==================== Epoch: 13/50 ... Step: 232... Loss: 2.2840... Validation Loss: 2.2994... ====================
# ==================== Epoch: 13/50 ... Step: 234... Loss: 2.2797... Validation Loss: 2.2909... ====================
# ==================== Epoch: 13/50 ... Step: 236... Loss: 2.2639... Validation Loss: 2.2977... ====================
# ==================== Epoch: 13/50 ... Step: 238... Loss: 2.2607... Validation Loss: 2.2910... ====================
# ==================== Epoch: 13/50 ... Step: 240... Loss: 2.2520... Validation Loss: 2.2820... ====================
# ==================== Epoch: 13/50 ... Step: 242... Loss: 2.2566... Validation Loss: 2.2843... ====================
# ==================== Epoch: 13/50 ... Step: 244... Loss: 2.2531... Validation Loss: 2.2797... ====================
# ==================== Epoch: 13/50 ... Step: 246... Loss: 2.2555... Validation Loss: 2.2772... ====================
# ==================== Epoch: 14/50 ... Step: 248... Loss: 2.2746... Validation Loss: 2.2733... ====================
# ==================== Epoch: 14/50 ... Step: 250... Loss: 2.2715... Validation Loss: 2.2725... ====================
# ==================== Epoch: 14/50 ... Step: 252... Loss: 2.2409... Validation Loss: 2.2644... ====================
# ==================== Epoch: 14/50 ... Step: 254... Loss: 2.2302... Validation Loss: 2.2647... ====================
# ==================== Epoch: 14/50 ... Step: 256... Loss: 2.2299... Validation Loss: 2.2678... ====================
# ==================== Epoch: 14/50 ... Step: 258... Loss: 2.2467... Validation Loss: 2.2586... ====================
# ==================== Epoch: 14/50 ... Step: 260... Loss: 2.2594... Validation Loss: 2.2593... ====================
# ==================== Epoch: 14/50 ... Step: 262... Loss: 2.2483... Validation Loss: 2.2598... ====================
# ==================== Epoch: 14/50 ... Step: 264... Loss: 2.2185... Validation Loss: 2.2628... ====================
# ==================== Epoch: 14/50 ... Step: 266... Loss: 2.2596... Validation Loss: 2.2492... ====================
# ==================== Epoch: 15/50 ... Step: 268... Loss: 2.2502... Validation Loss: 2.2462... ====================
# ==================== Epoch: 15/50 ... Step: 270... Loss: 2.2371... Validation Loss: 2.2480... ====================
# ==================== Epoch: 15/50 ... Step: 272... Loss: 2.2214... Validation Loss: 2.2408... ====================
# ==================== Epoch: 15/50 ... Step: 274... Loss: 2.2141... Validation Loss: 2.2476... ====================
# ==================== Epoch: 15/50 ... Step: 276... Loss: 2.2156... Validation Loss: 2.2412... ====================
# ==================== Epoch: 15/50 ... Step: 278... Loss: 2.2079... Validation Loss: 2.2406... ====================
# ==================== Epoch: 15/50 ... Step: 280... Loss: 2.1958... Validation Loss: 2.2390... ====================
# ==================== Epoch: 15/50 ... Step: 282... Loss: 2.2092... Validation Loss: 2.2368... ====================
# ==================== Epoch: 15/50 ... Step: 284... Loss: 2.2005... Validation Loss: 2.2342... ====================
# ==================== Epoch: 16/50 ... Step: 286... Loss: 2.2300... Validation Loss: 2.2312... ====================
# ==================== Epoch: 16/50 ... Step: 288... Loss: 2.2203... Validation Loss: 2.2254... ====================
# ==================== Epoch: 16/50 ... Step: 290... Loss: 2.1943... Validation Loss: 2.2285... ====================
# ==================== Epoch: 16/50 ... Step: 292... Loss: 2.1912... Validation Loss: 2.2284... ====================
# ==================== Epoch: 16/50 ... Step: 294... Loss: 2.1761... Validation Loss: 2.2259... ====================
# ==================== Epoch: 16/50 ... Step: 296... Loss: 2.1956... Validation Loss: 2.2196... ====================
# ==================== Epoch: 16/50 ... Step: 298... Loss: 2.2123... Validation Loss: 2.2256... ====================
# ==================== Epoch: 16/50 ... Step: 300... Loss: 2.2054... Validation Loss: 2.2212... ====================
# ==================== Epoch: 16/50 ... Step: 302... Loss: 2.1809... Validation Loss: 2.2137... ====================
# ==================== Epoch: 16/50 ... Step: 304... Loss: 2.2115... Validation Loss: 2.2211... ====================
# ==================== Epoch: 17/50 ... Step: 306... Loss: 2.2046... Validation Loss: 2.2106... ====================
# ==================== Epoch: 17/50 ... Step: 308... Loss: 2.1932... Validation Loss: 2.2108... ====================
# ==================== Epoch: 17/50 ... Step: 310... Loss: 2.1927... Validation Loss: 2.2133... ====================
# ==================== Epoch: 17/50 ... Step: 312... Loss: 2.1733... Validation Loss: 2.2075... ====================
# ==================== Epoch: 17/50 ... Step: 314... Loss: 2.1731... Validation Loss: 2.2044... ====================
# ==================== Epoch: 17/50 ... Step: 316... Loss: 2.1594... Validation Loss: 2.2063... ====================
# ==================== Epoch: 17/50 ... Step: 318... Loss: 2.1622... Validation Loss: 2.2058... ====================
# ==================== Epoch: 17/50 ... Step: 320... Loss: 2.1681... Validation Loss: 2.2008... ====================
# ==================== Epoch: 17/50 ... Step: 322... Loss: 2.1686... Validation Loss: 2.2061... ====================
# ==================== Epoch: 18/50 ... Step: 324... Loss: 2.1923... Validation Loss: 2.2011... ====================
# ==================== Epoch: 18/50 ... Step: 326... Loss: 2.1893... Validation Loss: 2.2054... ====================
# ==================== Epoch: 18/50 ... Step: 328... Loss: 2.1513... Validation Loss: 2.2060... ====================
# ==================== Epoch: 18/50 ... Step: 330... Loss: 2.1540... Validation Loss: 2.2043... ====================
# ==================== Epoch: 18/50 ... Step: 332... Loss: 2.1492... Validation Loss: 2.1960... ====================
# ==================== Epoch: 18/50 ... Step: 334... Loss: 2.1655... Validation Loss: 2.2067... ====================
# ==================== Epoch: 18/50 ... Step: 336... Loss: 2.1748... Validation Loss: 2.1906... ====================
# ==================== Epoch: 18/50 ... Step: 338... Loss: 2.1707... Validation Loss: 2.1947... ====================
# ==================== Epoch: 18/50 ... Step: 340... Loss: 2.1374... Validation Loss: 2.1925... ====================
# ==================== Epoch: 18/50 ... Step: 342... Loss: 2.1739... Validation Loss: 2.1957... ====================
# ==================== Epoch: 19/50 ... Step: 344... Loss: 2.1684... Validation Loss: 2.1871... ====================
# ==================== Epoch: 19/50 ... Step: 346... Loss: 2.1502... Validation Loss: 2.1804... ====================
# ==================== Epoch: 19/50 ... Step: 348... Loss: 2.1452... Validation Loss: 2.1840... ====================
# ==================== Epoch: 19/50 ... Step: 350... Loss: 2.1323... Validation Loss: 2.1880... ====================
# ==================== Epoch: 19/50 ... Step: 352... Loss: 2.1352... Validation Loss: 2.1764... ====================
# ==================== Epoch: 19/50 ... Step: 354... Loss: 2.1239... Validation Loss: 2.1810... ====================
# ==================== Epoch: 19/50 ... Step: 356... Loss: 2.1253... Validation Loss: 2.1780... ====================
# ==================== Epoch: 19/50 ... Step: 358... Loss: 2.1386... Validation Loss: 2.1767... ====================
# ==================== Epoch: 19/50 ... Step: 360... Loss: 2.1241... Validation Loss: 2.1795... ====================
# ==================== Epoch: 20/50 ... Step: 362... Loss: 2.1513... Validation Loss: 2.1782... ====================
# ==================== Epoch: 20/50 ... Step: 364... Loss: 2.1410... Validation Loss: 2.1795... ====================
# ==================== Epoch: 20/50 ... Step: 366... Loss: 2.1180... Validation Loss: 2.1816... ====================
# ==================== Epoch: 20/50 ... Step: 368... Loss: 2.1095... Validation Loss: 2.1799... ====================
# ==================== Epoch: 20/50 ... Step: 370... Loss: 2.1136... Validation Loss: 2.1738... ====================
# ==================== Epoch: 20/50 ... Step: 372... Loss: 2.1334... Validation Loss: 2.1774... ====================
# ==================== Epoch: 20/50 ... Step: 374... Loss: 2.1218... Validation Loss: 2.1690... ====================
# ==================== Epoch: 20/50 ... Step: 376... Loss: 2.1418... Validation Loss: 2.1699... ====================
# ==================== Epoch: 20/50 ... Step: 378... Loss: 2.1076... Validation Loss: 2.1649... ====================
# ==================== Epoch: 20/50 ... Step: 380... Loss: 2.1470... Validation Loss: 2.1689... ====================
# ==================== Epoch: 21/50 ... Step: 382... Loss: 2.1303... Validation Loss: 2.1651... ====================
# ==================== Epoch: 21/50 ... Step: 384... Loss: 2.1299... Validation Loss: 2.1773... ====================
# ==================== Epoch: 21/50 ... Step: 386... Loss: 2.1221... Validation Loss: 2.1726... ====================
# ==================== Epoch: 21/50 ... Step: 388... Loss: 2.1109... Validation Loss: 2.1683... ====================
# ==================== Epoch: 21/50 ... Step: 390... Loss: 2.1140... Validation Loss: 2.1714... ====================
# ==================== Epoch: 21/50 ... Step: 392... Loss: 2.1013... Validation Loss: 2.1690... ====================
# ==================== Epoch: 21/50 ... Step: 394... Loss: 2.0909... Validation Loss: 2.1606... ====================
# ==================== Epoch: 21/50 ... Step: 396... Loss: 2.1139... Validation Loss: 2.1595... ====================
# ==================== Epoch: 21/50 ... Step: 398... Loss: 2.0888... Validation Loss: 2.1621... ====================
# ==================== Epoch: 22/50 ... Step: 400... Loss: 2.1290... Validation Loss: 2.1633... ====================
# ==================== Epoch: 22/50 ... Step: 402... Loss: 2.1105... Validation Loss: 2.1538... ====================
# ==================== Epoch: 22/50 ... Step: 404... Loss: 2.0910... Validation Loss: 2.1599... ====================
# ==================== Epoch: 22/50 ... Step: 406... Loss: 2.0749... Validation Loss: 2.1556... ====================
# ==================== Epoch: 22/50 ... Step: 408... Loss: 2.0843... Validation Loss: 2.1527... ====================
# ==================== Epoch: 22/50 ... Step: 410... Loss: 2.0983... Validation Loss: 2.1524... ====================
# ==================== Epoch: 22/50 ... Step: 412... Loss: 2.0982... Validation Loss: 2.1535... ====================
# ==================== Epoch: 22/50 ... Step: 414... Loss: 2.0961... Validation Loss: 2.1523... ====================
# ==================== Epoch: 22/50 ... Step: 416... Loss: 2.0735... Validation Loss: 2.1460... ====================
# ==================== Epoch: 22/50 ... Step: 418... Loss: 2.1084... Validation Loss: 2.1512... ====================
# ==================== Epoch: 23/50 ... Step: 420... Loss: 2.1003... Validation Loss: 2.1413... ====================
# ==================== Epoch: 23/50 ... Step: 422... Loss: 2.0900... Validation Loss: 2.1440... ====================
# ==================== Epoch: 23/50 ... Step: 424... Loss: 2.0800... Validation Loss: 2.1403... ====================
# ==================== Epoch: 23/50 ... Step: 426... Loss: 2.0769... Validation Loss: 2.1403... ====================
# ==================== Epoch: 23/50 ... Step: 428... Loss: 2.0714... Validation Loss: 2.1364... ====================
# ==================== Epoch: 23/50 ... Step: 430... Loss: 2.0687... Validation Loss: 2.1409... ====================
# ==================== Epoch: 23/50 ... Step: 432... Loss: 2.0634... Validation Loss: 2.1434... ====================
# ==================== Epoch: 23/50 ... Step: 434... Loss: 2.0667... Validation Loss: 2.1369... ====================
# ==================== Epoch: 23/50 ... Step: 436... Loss: 2.0572... Validation Loss: 2.1429... ====================
# ==================== Epoch: 24/50 ... Step: 438... Loss: 2.0950... Validation Loss: 2.1322... ====================
# ==================== Epoch: 24/50 ... Step: 440... Loss: 2.0879... Validation Loss: 2.1416... ====================
# ==================== Epoch: 24/50 ... Step: 442... Loss: 2.0542... Validation Loss: 2.1449... ====================
# ==================== Epoch: 24/50 ... Step: 444... Loss: 2.0515... Validation Loss: 2.1324... ====================
# ==================== Epoch: 24/50 ... Step: 446... Loss: 2.0562... Validation Loss: 2.1297... ====================
# ==================== Epoch: 24/50 ... Step: 448... Loss: 2.0677... Validation Loss: 2.1385... ====================
# ==================== Epoch: 24/50 ... Step: 450... Loss: 2.0656... Validation Loss: 2.1418... ====================
# ==================== Epoch: 24/50 ... Step: 452... Loss: 2.0632... Validation Loss: 2.1303... ====================
# ==================== Epoch: 24/50 ... Step: 454... Loss: 2.0520... Validation Loss: 2.1328... ====================
# ==================== Epoch: 24/50 ... Step: 456... Loss: 2.0815... Validation Loss: 2.1391... ====================
# ==================== Epoch: 25/50 ... Step: 458... Loss: 2.0658... Validation Loss: 2.1215... ====================
# ==================== Epoch: 25/50 ... Step: 460... Loss: 2.0600... Validation Loss: 2.1276... ====================
# ==================== Epoch: 25/50 ... Step: 462... Loss: 2.0570... Validation Loss: 2.1279... ====================
# ==================== Epoch: 25/50 ... Step: 464... Loss: 2.0483... Validation Loss: 2.1239... ====================
# ==================== Epoch: 25/50 ... Step: 466... Loss: 2.0442... Validation Loss: 2.1334... ====================
# ==================== Epoch: 25/50 ... Step: 468... Loss: 2.0445... Validation Loss: 2.1318... ====================
# ==================== Epoch: 25/50 ... Step: 470... Loss: 2.0286... Validation Loss: 2.1239... ====================
# ==================== Epoch: 25/50 ... Step: 472... Loss: 2.0307... Validation Loss: 2.1257... ====================
# ==================== Epoch: 25/50 ... Step: 474... Loss: 2.0280... Validation Loss: 2.1262... ====================
# ==================== Epoch: 26/50 ... Step: 476... Loss: 2.0640... Validation Loss: 2.1243... ====================
# ==================== Epoch: 26/50 ... Step: 478... Loss: 2.0560... Validation Loss: 2.1202... ====================
# ==================== Epoch: 26/50 ... Step: 480... Loss: 2.0168... Validation Loss: 2.1193... ====================
# ==================== Epoch: 26/50 ... Step: 482... Loss: 2.0146... Validation Loss: 2.1207... ====================
# ==================== Epoch: 26/50 ... Step: 484... Loss: 2.0154... Validation Loss: 2.1196... ====================
# ==================== Epoch: 26/50 ... Step: 486... Loss: 2.0276... Validation Loss: 2.1181... ====================
# ==================== Epoch: 26/50 ... Step: 488... Loss: 2.0342... Validation Loss: 2.1126... ====================
# ==================== Epoch: 26/50 ... Step: 490... Loss: 2.0379... Validation Loss: 2.1085... ====================
# ==================== Epoch: 26/50 ... Step: 492... Loss: 2.0112... Validation Loss: 2.1139... ====================
# ==================== Epoch: 26/50 ... Step: 494... Loss: 2.0473... Validation Loss: 2.1165... ====================
# ==================== Epoch: 27/50 ... Step: 496... Loss: 2.0313... Validation Loss: 2.1159... ====================
# ==================== Epoch: 27/50 ... Step: 498... Loss: 2.0199... Validation Loss: 2.1052... ====================
# ==================== Epoch: 27/50 ... Step: 500... Loss: 2.0230... Validation Loss: 2.1118... ====================
# ==================== Epoch: 27/50 ... Step: 502... Loss: 2.0151... Validation Loss: 2.1115... ====================
# ==================== Epoch: 27/50 ... Step: 504... Loss: 2.0210... Validation Loss: 2.1107... ====================
# ==================== Epoch: 27/50 ... Step: 506... Loss: 2.0087... Validation Loss: 2.1064... ====================
# ==================== Epoch: 27/50 ... Step: 508... Loss: 1.9899... Validation Loss: 2.1120... ====================
# ==================== Epoch: 27/50 ... Step: 510... Loss: 2.0017... Validation Loss: 2.1040... ====================
# ==================== Epoch: 27/50 ... Step: 512... Loss: 1.9867... Validation Loss: 2.1125... ====================
# ==================== Epoch: 28/50 ... Step: 514... Loss: 2.0344... Validation Loss: 2.1068... ====================
# ==================== Epoch: 28/50 ... Step: 516... Loss: 2.0129... Validation Loss: 2.1006... ====================
# ==================== Epoch: 28/50 ... Step: 518... Loss: 1.9861... Validation Loss: 2.1044... ====================
# ==================== Epoch: 28/50 ... Step: 520... Loss: 1.9884... Validation Loss: 2.0990... ====================
# ==================== Epoch: 28/50 ... Step: 522... Loss: 1.9843... Validation Loss: 2.1015... ====================
# ==================== Epoch: 28/50 ... Step: 524... Loss: 1.9988... Validation Loss: 2.1065... ====================
# ==================== Epoch: 28/50 ... Step: 526... Loss: 2.0091... Validation Loss: 2.1027... ====================
# ==================== Epoch: 28/50 ... Step: 528... Loss: 1.9962... Validation Loss: 2.1003... ====================
# ==================== Epoch: 28/50 ... Step: 530... Loss: 1.9864... Validation Loss: 2.1016... ====================
# ==================== Epoch: 28/50 ... Step: 532... Loss: 2.0193... Validation Loss: 2.1040... ====================
# ==================== Epoch: 29/50 ... Step: 534... Loss: 2.0019... Validation Loss: 2.1072... ====================
# ==================== Epoch: 29/50 ... Step: 536... Loss: 2.0032... Validation Loss: 2.1135... ====================
# ==================== Epoch: 29/50 ... Step: 538... Loss: 1.9890... Validation Loss: 2.0907... ====================
# ==================== Epoch: 29/50 ... Step: 540... Loss: 1.9930... Validation Loss: 2.1038... ====================
# ==================== Epoch: 29/50 ... Step: 542... Loss: 1.9894... Validation Loss: 2.0982... ====================
# ==================== Epoch: 29/50 ... Step: 544... Loss: 1.9874... Validation Loss: 2.1042... ====================
# ==================== Epoch: 29/50 ... Step: 546... Loss: 1.9712... Validation Loss: 2.1024... ====================
# ==================== Epoch: 29/50 ... Step: 548... Loss: 1.9735... Validation Loss: 2.1019... ====================
# ==================== Epoch: 29/50 ... Step: 550... Loss: 1.9688... Validation Loss: 2.0988... ====================
# ==================== Epoch: 30/50 ... Step: 552... Loss: 2.0145... Validation Loss: 2.0972... ====================
# ==================== Epoch: 30/50 ... Step: 554... Loss: 1.9978... Validation Loss: 2.0970... ====================
# ==================== Epoch: 30/50 ... Step: 556... Loss: 1.9669... Validation Loss: 2.0947... ====================
# ==================== Epoch: 30/50 ... Step: 558... Loss: 1.9608... Validation Loss: 2.0909... ====================
# ==================== Epoch: 30/50 ... Step: 560... Loss: 1.9534... Validation Loss: 2.0956... ====================
# ==================== Epoch: 30/50 ... Step: 562... Loss: 1.9680... Validation Loss: 2.0984... ====================
# ==================== Epoch: 30/50 ... Step: 564... Loss: 1.9740... Validation Loss: 2.0987... ====================
# ==================== Epoch: 30/50 ... Step: 566... Loss: 1.9621... Validation Loss: 2.0986... ====================
# ==================== Epoch: 30/50 ... Step: 568... Loss: 1.9502... Validation Loss: 2.0940... ====================
# ==================== Epoch: 30/50 ... Step: 570... Loss: 1.9824... Validation Loss: 2.0973... ====================
# ==================== Epoch: 31/50 ... Step: 572... Loss: 1.9670... Validation Loss: 2.0929... ====================
# ==================== Epoch: 31/50 ... Step: 574... Loss: 1.9592... Validation Loss: 2.0891... ====================
# ==================== Epoch: 31/50 ... Step: 576... Loss: 1.9545... Validation Loss: 2.0801... ====================
# ==================== Epoch: 31/50 ... Step: 578... Loss: 1.9616... Validation Loss: 2.0819... ====================
# ==================== Epoch: 31/50 ... Step: 580... Loss: 1.9479... Validation Loss: 2.0885... ====================
# ==================== Epoch: 31/50 ... Step: 582... Loss: 1.9580... Validation Loss: 2.0908... ====================
# ==================== Epoch: 31/50 ... Step: 584... Loss: 1.9274... Validation Loss: 2.0928... ====================
# ==================== Epoch: 31/50 ... Step: 586... Loss: 1.9465... Validation Loss: 2.0904... ====================
# ==================== Epoch: 31/50 ... Step: 588... Loss: 1.9287... Validation Loss: 2.1002... ====================
# ==================== Epoch: 32/50 ... Step: 590... Loss: 1.9780... Validation Loss: 2.0956... ====================
# ==================== Epoch: 32/50 ... Step: 592... Loss: 1.9594... Validation Loss: 2.0902... ====================
# ==================== Epoch: 32/50 ... Step: 594... Loss: 1.9319... Validation Loss: 2.1020... ====================
# ==================== Epoch: 32/50 ... Step: 596... Loss: 1.9264... Validation Loss: 2.0747... ====================
# ==================== Epoch: 32/50 ... Step: 598... Loss: 1.9199... Validation Loss: 2.0822... ====================
# ==================== Epoch: 32/50 ... Step: 600... Loss: 1.9475... Validation Loss: 2.0941... ====================
# ==================== Epoch: 32/50 ... Step: 602... Loss: 1.9375... Validation Loss: 2.0840... ====================
# ==================== Epoch: 32/50 ... Step: 604... Loss: 1.9362... Validation Loss: 2.0895... ====================
# ==================== Epoch: 32/50 ... Step: 606... Loss: 1.9283... Validation Loss: 2.0912... ====================
# ==================== Epoch: 32/50 ... Step: 608... Loss: 1.9691... Validation Loss: 2.0817... ====================
# ==================== Epoch: 33/50 ... Step: 610... Loss: 1.9432... Validation Loss: 2.1047... ====================
# ==================== Epoch: 33/50 ... Step: 612... Loss: 1.9296... Validation Loss: 2.0941... ====================
# ==================== Epoch: 33/50 ... Step: 614... Loss: 1.9366... Validation Loss: 2.0953... ====================
# ==================== Epoch: 33/50 ... Step: 616... Loss: 1.9529... Validation Loss: 2.0855... ====================
# ==================== Epoch: 33/50 ... Step: 618... Loss: 1.9406... Validation Loss: 2.0926... ====================
# ==================== Epoch: 33/50 ... Step: 620... Loss: 1.9243... Validation Loss: 2.0933... ====================
# ==================== Epoch: 33/50 ... Step: 622... Loss: 1.9074... Validation Loss: 2.0981... ====================
# ==================== Epoch: 33/50 ... Step: 624... Loss: 1.9162... Validation Loss: 2.0819... ====================
# ==================== Epoch: 33/50 ... Step: 626... Loss: 1.9043... Validation Loss: 2.0831... ====================
# ==================== Epoch: 34/50 ... Step: 628... Loss: 1.9619... Validation Loss: 2.0802... ====================
# ==================== Epoch: 34/50 ... Step: 630... Loss: 1.9422... Validation Loss: 2.0832... ====================
# ==================== Epoch: 34/50 ... Step: 632... Loss: 1.9077... Validation Loss: 2.0889... ====================
# ==================== Epoch: 34/50 ... Step: 634... Loss: 1.9222... Validation Loss: 2.0844... ====================
# ==================== Epoch: 34/50 ... Step: 636... Loss: 1.8969... Validation Loss: 2.0823... ====================
# ==================== Epoch: 34/50 ... Step: 638... Loss: 1.9307... Validation Loss: 2.0897... ====================
# ==================== Epoch: 34/50 ... Step: 640... Loss: 1.9207... Validation Loss: 2.0867... ====================
# ==================== Epoch: 34/50 ... Step: 642... Loss: 1.9166... Validation Loss: 2.0850... ====================
# ==================== Epoch: 34/50 ... Step: 644... Loss: 1.9012... Validation Loss: 2.0875... ====================
# ==================== Epoch: 34/50 ... Step: 646... Loss: 1.9437... Validation Loss: 2.0806... ====================
# ==================== Epoch: 35/50 ... Step: 648... Loss: 1.9210... Validation Loss: 2.0848... ====================
# ==================== Epoch: 35/50 ... Step: 650... Loss: 1.9153... Validation Loss: 2.0756... ====================
# ==================== Epoch: 35/50 ... Step: 652... Loss: 1.9029... Validation Loss: 2.0773... ====================
# ==================== Epoch: 35/50 ... Step: 654... Loss: 1.9291... Validation Loss: 2.0723... ====================
# ==================== Epoch: 35/50 ... Step: 656... Loss: 1.9028... Validation Loss: 2.0868... ====================
# ==================== Epoch: 35/50 ... Step: 658... Loss: 1.8874... Validation Loss: 2.0846... ====================
# ==================== Epoch: 35/50 ... Step: 660... Loss: 1.8793... Validation Loss: 2.0856... ====================
# ==================== Epoch: 35/50 ... Step: 662... Loss: 1.8927... Validation Loss: 2.0791... ====================
# ==================== Epoch: 35/50 ... Step: 664... Loss: 1.8750... Validation Loss: 2.0849... ====================
# ==================== Epoch: 36/50 ... Step: 666... Loss: 1.9316... Validation Loss: 2.0778... ====================
# ==================== Epoch: 36/50 ... Step: 668... Loss: 1.9111... Validation Loss: 2.0978... ====================
# ==================== Epoch: 36/50 ... Step: 670... Loss: 1.8834... Validation Loss: 2.0821... ====================
# ==================== Epoch: 36/50 ... Step: 672... Loss: 1.8817... Validation Loss: 2.0708... ====================
# ==================== Epoch: 36/50 ... Step: 674... Loss: 1.8746... Validation Loss: 2.0761... ====================
# ==================== Epoch: 36/50 ... Step: 676... Loss: 1.8843... Validation Loss: 2.0863... ====================
# ==================== Epoch: 36/50 ... Step: 678... Loss: 1.8867... Validation Loss: 2.0918... ====================
# ==================== Epoch: 36/50 ... Step: 680... Loss: 1.8684... Validation Loss: 2.0842... ====================
# ==================== Epoch: 36/50 ... Step: 682... Loss: 1.8690... Validation Loss: 2.0783... ====================
# ==================== Epoch: 36/50 ... Step: 684... Loss: 1.9140... Validation Loss: 2.0847... ====================
# ==================== Epoch: 37/50 ... Step: 686... Loss: 1.8855... Validation Loss: 2.0822... ====================
# ==================== Epoch: 37/50 ... Step: 688... Loss: 1.8834... Validation Loss: 2.0810... ====================
# ==================== Epoch: 37/50 ... Step: 690... Loss: 1.8682... Validation Loss: 2.0771... ====================
# ==================== Epoch: 37/50 ... Step: 692... Loss: 1.8900... Validation Loss: 2.0690... ====================
# ==================== Epoch: 37/50 ... Step: 694... Loss: 1.8885... Validation Loss: 2.0828... ====================
# ==================== Epoch: 37/50 ... Step: 696... Loss: 1.8678... Validation Loss: 2.0802... ====================
# ==================== Epoch: 37/50 ... Step: 698... Loss: 1.8485... Validation Loss: 2.0779... ====================
# ==================== Epoch: 37/50 ... Step: 700... Loss: 1.8600... Validation Loss: 2.0846... ====================
# ==================== Epoch: 37/50 ... Step: 702... Loss: 1.8514... Validation Loss: 2.0818... ====================
# ==================== Epoch: 38/50 ... Step: 704... Loss: 1.9063... Validation Loss: 2.0812... ====================
# ==================== Epoch: 38/50 ... Step: 706... Loss: 1.8820... Validation Loss: 2.0803... ====================
# ==================== Epoch: 38/50 ... Step: 708... Loss: 1.8533... Validation Loss: 2.0727... ====================
# ==================== Epoch: 38/50 ... Step: 710... Loss: 1.8573... Validation Loss: 2.0795... ====================
# ==================== Epoch: 38/50 ... Step: 712... Loss: 1.8475... Validation Loss: 2.0645... ====================
# ==================== Epoch: 38/50 ... Step: 714... Loss: 1.8542... Validation Loss: 2.0866... ====================
# ==================== Epoch: 38/50 ... Step: 716... Loss: 1.8552... Validation Loss: 2.0834... ====================
# ==================== Epoch: 38/50 ... Step: 718... Loss: 1.8513... Validation Loss: 2.0792... ====================
# ==================== Epoch: 38/50 ... Step: 720... Loss: 1.8527... Validation Loss: 2.0819... ====================
# ==================== Epoch: 38/50 ... Step: 722... Loss: 1.8746... Validation Loss: 2.0813... ====================
# ==================== Epoch: 39/50 ... Step: 724... Loss: 1.8544... Validation Loss: 2.0808... ====================
# ==================== Epoch: 39/50 ... Step: 726... Loss: 1.8519... Validation Loss: 2.0802... ====================
# ==================== Epoch: 39/50 ... Step: 728... Loss: 1.8435... Validation Loss: 2.0739... ====================
# ==================== Epoch: 39/50 ... Step: 730... Loss: 1.8572... Validation Loss: 2.0642... ====================
# ==================== Epoch: 39/50 ... Step: 732... Loss: 1.8626... Validation Loss: 2.0760... ====================
# ==================== Epoch: 39/50 ... Step: 734... Loss: 1.8359... Validation Loss: 2.0842... ====================
# ==================== Epoch: 39/50 ... Step: 736... Loss: 1.8180... Validation Loss: 2.0742... ====================
# ==================== Epoch: 39/50 ... Step: 738... Loss: 1.8194... Validation Loss: 2.0708... ====================
# ==================== Epoch: 39/50 ... Step: 740... Loss: 1.8129... Validation Loss: 2.0781... ====================
# ==================== Epoch: 40/50 ... Step: 742... Loss: 1.8789... Validation Loss: 2.0818... ====================
# ==================== Epoch: 40/50 ... Step: 744... Loss: 1.8503... Validation Loss: 2.0785... ====================
# ==================== Epoch: 40/50 ... Step: 746... Loss: 1.8169... Validation Loss: 2.0763... ====================
# ==================== Epoch: 40/50 ... Step: 748... Loss: 1.8268... Validation Loss: 2.0791... ====================
# ==================== Epoch: 40/50 ... Step: 750... Loss: 1.8214... Validation Loss: 2.0531... ====================
# ==================== Epoch: 40/50 ... Step: 752... Loss: 1.8176... Validation Loss: 2.0798... ====================
# ==================== Epoch: 40/50 ... Step: 754... Loss: 1.8172... Validation Loss: 2.0797... ====================
# ==================== Epoch: 40/50 ... Step: 756... Loss: 1.8236... Validation Loss: 2.0701... ====================
# ==================== Epoch: 40/50 ... Step: 758... Loss: 1.8090... Validation Loss: 2.0901... ====================
# ==================== Epoch: 40/50 ... Step: 760... Loss: 1.8381... Validation Loss: 2.0764... ====================
# ==================== Epoch: 41/50 ... Step: 762... Loss: 1.8334... Validation Loss: 2.0806... ====================
# ==================== Epoch: 41/50 ... Step: 764... Loss: 1.8188... Validation Loss: 2.0741... ====================
# ==================== Epoch: 41/50 ... Step: 766... Loss: 1.8112... Validation Loss: 2.0731... ====================
# ==================== Epoch: 41/50 ... Step: 768... Loss: 1.8371... Validation Loss: 2.0670... ====================
# ==================== Epoch: 41/50 ... Step: 770... Loss: 1.8329... Validation Loss: 2.0723... ====================
# ==================== Epoch: 41/50 ... Step: 772... Loss: 1.8008... Validation Loss: 2.0767... ====================
# ==================== Epoch: 41/50 ... Step: 774... Loss: 1.7887... Validation Loss: 2.0733... ====================
# ==================== Epoch: 41/50 ... Step: 776... Loss: 1.7989... Validation Loss: 2.0754... ====================
# ==================== Epoch: 41/50 ... Step: 778... Loss: 1.7882... Validation Loss: 2.0865... ====================
# ==================== Epoch: 42/50 ... Step: 780... Loss: 1.8558... Validation Loss: 2.0842... ====================
# ==================== Epoch: 42/50 ... Step: 782... Loss: 1.8114... Validation Loss: 2.0783... ====================
# ==================== Epoch: 42/50 ... Step: 784... Loss: 1.7850... Validation Loss: 2.0875... ====================
# ==================== Epoch: 42/50 ... Step: 786... Loss: 1.8015... Validation Loss: 2.0859... ====================
# ==================== Epoch: 42/50 ... Step: 788... Loss: 1.7947... Validation Loss: 2.0667... ====================
# ==================== Epoch: 42/50 ... Step: 790... Loss: 1.8110... Validation Loss: 2.0559... ====================
# ==================== Epoch: 42/50 ... Step: 792... Loss: 1.7915... Validation Loss: 2.0934... ====================
# ==================== Epoch: 42/50 ... Step: 794... Loss: 1.7984... Validation Loss: 2.0656... ====================
# ==================== Epoch: 42/50 ... Step: 796... Loss: 1.7810... Validation Loss: 2.0800... ====================
# ==================== Epoch: 42/50 ... Step: 798... Loss: 1.8139... Validation Loss: 2.1109... ====================
# ==================== Epoch: 43/50 ... Step: 800... Loss: 1.7970... Validation Loss: 2.0811... ====================
# ==================== Epoch: 43/50 ... Step: 802... Loss: 1.7941... Validation Loss: 2.0776... ====================
# ==================== Epoch: 43/50 ... Step: 804... Loss: 1.7824... Validation Loss: 2.0880... ====================
# ==================== Epoch: 43/50 ... Step: 806... Loss: 1.7950... Validation Loss: 2.0718... ====================
# ==================== Epoch: 43/50 ... Step: 808... Loss: 1.8074... Validation Loss: 2.0587... ====================
# ==================== Epoch: 43/50 ... Step: 810... Loss: 1.7723... Validation Loss: 2.0709... ====================
# ==================== Epoch: 43/50 ... Step: 812... Loss: 1.7546... Validation Loss: 2.0848... ====================
# ==================== Epoch: 43/50 ... Step: 814... Loss: 1.7767... Validation Loss: 2.0689... ====================
# ==================== Epoch: 43/50 ... Step: 816... Loss: 1.7685... Validation Loss: 2.0863... ====================
# ==================== Epoch: 44/50 ... Step: 818... Loss: 1.8223... Validation Loss: 2.0956... ====================
# ==================== Epoch: 44/50 ... Step: 820... Loss: 1.7974... Validation Loss: 2.0783... ====================
# ==================== Epoch: 44/50 ... Step: 822... Loss: 1.7643... Validation Loss: 2.0767... ====================
# ==================== Epoch: 44/50 ... Step: 824... Loss: 1.7725... Validation Loss: 2.0800... ====================
# ==================== Epoch: 44/50 ... Step: 826... Loss: 1.7567... Validation Loss: 2.0876... ====================
# ==================== Epoch: 44/50 ... Step: 828... Loss: 1.7731... Validation Loss: 2.0612... ====================
# ==================== Epoch: 44/50 ... Step: 830... Loss: 1.7696... Validation Loss: 2.0746... ====================
# ==================== Epoch: 44/50 ... Step: 832... Loss: 1.7594... Validation Loss: 2.0789... ====================
# ==================== Epoch: 44/50 ... Step: 834... Loss: 1.7643... Validation Loss: 2.0829... ====================
# ==================== Epoch: 44/50 ... Step: 836... Loss: 1.7921... Validation Loss: 2.0869... ====================
# ==================== Epoch: 45/50 ... Step: 838... Loss: 1.7713... Validation Loss: 2.1081... ====================
# ==================== Epoch: 45/50 ... Step: 840... Loss: 1.7627... Validation Loss: 2.0853... ====================
# ==================== Epoch: 45/50 ... Step: 842... Loss: 1.7631... Validation Loss: 2.0855... ====================
# ==================== Epoch: 45/50 ... Step: 844... Loss: 1.7724... Validation Loss: 2.0653... ====================
# ==================== Epoch: 45/50 ... Step: 846... Loss: 1.7742... Validation Loss: 2.0816... ====================
# ==================== Epoch: 45/50 ... Step: 848... Loss: 1.7470... Validation Loss: 2.0853... ====================
# ==================== Epoch: 45/50 ... Step: 850... Loss: 1.7286... Validation Loss: 2.0856... ====================
# ==================== Epoch: 45/50 ... Step: 852... Loss: 1.7409... Validation Loss: 2.0867... ====================
# ==================== Epoch: 45/50 ... Step: 854... Loss: 1.7321... Validation Loss: 2.0761... ====================
# ==================== Epoch: 46/50 ... Step: 856... Loss: 1.7941... Validation Loss: 2.1029... ====================
# ==================== Epoch: 46/50 ... Step: 858... Loss: 1.7595... Validation Loss: 2.1028... ====================
# ==================== Epoch: 46/50 ... Step: 860... Loss: 1.7347... Validation Loss: 2.0803... ====================
# ==================== Epoch: 46/50 ... Step: 862... Loss: 1.7442... Validation Loss: 2.0925... ====================
# ==================== Epoch: 46/50 ... Step: 864... Loss: 1.7320... Validation Loss: 2.0819... ====================
# ==================== Epoch: 46/50 ... Step: 866... Loss: 1.7389... Validation Loss: 2.0751... ====================
# ==================== Epoch: 46/50 ... Step: 868... Loss: 1.7457... Validation Loss: 2.0883... ====================
# ==================== Epoch: 46/50 ... Step: 870... Loss: 1.7262... Validation Loss: 2.0898... ====================
# ==================== Epoch: 46/50 ... Step: 872... Loss: 1.7297... Validation Loss: 2.0950... ====================
# ==================== Epoch: 46/50 ... Step: 874... Loss: 1.7776... Validation Loss: 2.0777... ====================
# ==================== Epoch: 47/50 ... Step: 876... Loss: 1.7349... Validation Loss: 2.1230... ====================
# ==================== Epoch: 47/50 ... Step: 878... Loss: 1.7326... Validation Loss: 2.0988... ====================
# ==================== Epoch: 47/50 ... Step: 880... Loss: 1.7276... Validation Loss: 2.0808... ====================
# ==================== Epoch: 47/50 ... Step: 882... Loss: 1.7494... Validation Loss: 2.0965... ====================
# ==================== Epoch: 47/50 ... Step: 884... Loss: 1.7366... Validation Loss: 2.0722... ====================
# ==================== Epoch: 47/50 ... Step: 886... Loss: 1.7112... Validation Loss: 2.0871... ====================
# ==================== Epoch: 47/50 ... Step: 888... Loss: 1.7033... Validation Loss: 2.0962... ====================
# ==================== Epoch: 47/50 ... Step: 890... Loss: 1.7158... Validation Loss: 2.1010... ====================
# ==================== Epoch: 47/50 ... Step: 892... Loss: 1.7118... Validation Loss: 2.0905... ====================
# ==================== Epoch: 48/50 ... Step: 894... Loss: 1.7861... Validation Loss: 2.0880... ====================
# ==================== Epoch: 48/50 ... Step: 896... Loss: 1.7264... Validation Loss: 2.1308... ====================
# ==================== Epoch: 48/50 ... Step: 898... Loss: 1.7039... Validation Loss: 2.0936... ====================
# ==================== Epoch: 48/50 ... Step: 900... Loss: 1.7275... Validation Loss: 2.0875... ====================
# ==================== Epoch: 48/50 ... Step: 902... Loss: 1.7058... Validation Loss: 2.0922... ====================
# ==================== Epoch: 48/50 ... Step: 904... Loss: 1.7217... Validation Loss: 2.0700... ====================
# ==================== Epoch: 48/50 ... Step: 906... Loss: 1.7054... Validation Loss: 2.0908... ====================
# ==================== Epoch: 48/50 ... Step: 908... Loss: 1.7222... Validation Loss: 2.0981... ====================
# ==================== Epoch: 48/50 ... Step: 910... Loss: 1.7205... Validation Loss: 2.0844... ====================
# ==================== Epoch: 48/50 ... Step: 912... Loss: 1.7285... Validation Loss: 2.1160... ====================
# ==================== Epoch: 49/50 ... Step: 914... Loss: 1.7108... Validation Loss: 2.1102... ====================
# ==================== Epoch: 49/50 ... Step: 916... Loss: 1.7036... Validation Loss: 2.1193... ====================
# ==================== Epoch: 49/50 ... Step: 918... Loss: 1.6999... Validation Loss: 2.0773... ====================
# ==================== Epoch: 49/50 ... Step: 920... Loss: 1.7118... Validation Loss: 2.1085... ====================
# ==================== Epoch: 49/50 ... Step: 922... Loss: 1.7185... Validation Loss: 2.0896... ====================
# ==================== Epoch: 49/50 ... Step: 924... Loss: 1.6947... Validation Loss: 2.0799... ====================
# ==================== Epoch: 49/50 ... Step: 926... Loss: 1.6702... Validation Loss: 2.1113... ====================
# ==================== Epoch: 49/50 ... Step: 928... Loss: 1.6927... Validation Loss: 2.0914... ====================
# ==================== Epoch: 49/50 ... Step: 930... Loss: 1.6817... Validation Loss: 2.0916... ====================
# ==================== Epoch: 50/50 ... Step: 932... Loss: 1.7568... Validation Loss: 2.1144... ====================
# ==================== Epoch: 50/50 ... Step: 934... Loss: 1.7033... Validation Loss: 2.1080... ====================
# ==================== Epoch: 50/50 ... Step: 936... Loss: 1.6828... Validation Loss: 2.1091... ====================
# ==================== Epoch: 50/50 ... Step: 938... Loss: 1.6933... Validation Loss: 2.0839... ====================
# ==================== Epoch: 50/50 ... Step: 940... Loss: 1.6800... Validation Loss: 2.1075... ====================
# ==================== Epoch: 50/50 ... Step: 942... Loss: 1.6966... Validation Loss: 2.0920... ====================
# ==================== Epoch: 50/50 ... Step: 944... Loss: 1.6911... Validation Loss: 2.0860... ====================
# ==================== Epoch: 50/50 ... Step: 946... Loss: 1.6888... Validation Loss: 2.1323... ====================
# ==================== Epoch: 50/50 ... Step: 948... Loss: 1.6844... Validation Loss: 2.1133... ====================
# ==================== Epoch: 50/50 ... Step: 950... Loss: 1.7111... Validation Loss: 2.0998... ====================

# %% [markdown]
# ## Getting the Best Model

# %%
checkpoint = {'n_hidden': net.n_hidden,
              'n_layers': net.n_layers,
              'state_dict': net.state_dict(),
              'tokens': net.chars}
with open('rnn.net', 'wb') as f:
    torch.save(checkpoint, f)

# %% [markdown]
# ## Sample the model

# %%
def sample(net,
          size,
          prime = 'The',
          top_k = None,
          cuda = False):
    
    if cuda:
        net.cuda()
    else:
        net.cpu()
    
    net.eval()
    
    chars = [character for character in prime]
    h = net.init_hidden(1)
    for character in prime:
        char, h = net.predict(character,
                              h,
                              cuda = cuda,
                              top_k = top_k)
    
    chars.append(char)
    
    for index in range(size):
        char, h = net.predict(chars[-1],
                              h,
                              cuda = cuda,
                              top_k = top_k)
        chars.append(char)
    
    return ''.join(chars)

# %%
print(sample(net,
             5000,
             prime = 'Aesop',
             top_k=5,
             cuda = False))
# Out:
# Aesop
# That's be arrugul sparting tages a surrain battommers and but the mers on the cortes is only of brocks this battering ship it
# Ass I see the little outs of dince
# Sen the dream draging dreams of the mart on that through the pigh and bring strubble
# And the pilling themest carrotor traised
# The sittomerid that trangion and sticks, better my spirted sected, and the serent call pose
# I save they are to adlight a sticks of my still tradge to bull of the pore and with the city faciou to make these me in a blum or the stareth
# We the bash of the pins it asson the coust and secred
# I crung allow the strough themild
# That's the simple offariss
# I ame cimalint first toother pactic ant merting
# And a thisked to ship a brake pigate
# I spon that along mill that climp ant market to the match
# I see the pley out of the black frem
# So I can a bod babage breedingershel out a pire asking the burlies and basiding
# She tones, the clossed to turn the break of burn in the break
# I'm a canny, I spread on the day the day turner on a sumbor
# Sectripping the crooks the pressed
# To calle spet a crook britche bring and cormities
# Ats when the peasent andiled the mangam brewning the space
# And I will spit it in my salder springs
# All of ships four tolled tall the shilly out the selent
# Somithing is solding as annellow shooking a than
# I wake of a cartang and all and still antections and stalloted cold sitch
# And where's han atching spotive somestard to manner the stirn and was to tell at a still then
# Blaim but on a bod of and a back and back
# Badered a strong and she the proturaty prumorace
# Assanged the charnest ald tricking times
# I see my seems for the spire toward with a baster pince moneters of the circling states befice they seens a coldrand
# I don't ragged to the mash to the carcon back
# Burny throw the stingies on the parcies it
# Stere the seaker soles to storm the parete stop onch a pricate and the promotes
# And all they way a poore to could the plead to muld my can to see my settler prome catter
# Make motherfucker bead to the stack
# Traged in a parn that cread a still of the plants and the bull
# The bendally porded of the plumper take man a to the sarvers and a pold mase the last the spine
# To been the dort deverseen pissing of the monstered
# Talking of the plan sompassion of the capatingle
# I strangamour the cruck sture the pornot all
# Shaveling my the mothir back alone time
# I clock the bencom will back to sunk in a place than better mere the place and the spers
# Whine improw timis thas senders to the span the both marnsholded
# And the chame and stel metal to before the bangs to the break or the with a bing and both bact of sended insode that stalling
# I'll be a part wings with miss im was a see as the past to a sore the buckle to be the muddle
# And I wanta kitchen that sit spended all they was and botter forsal canst can to mance the summer they said
# And I'm the burker the partats trace arting and cations then the sticker bottle
# What a let a pill bast the bead that deam them tround to chind
# I sat was the sat high toward to be something the prettice lifes off the munty mare to base the lumb and was the mile this menitifes
# The sterman telinations spast as one to crose and the misters
# To compose the stall and to my fienty to concres intoment turn
# That consicent an in the marter than allenticen
# But the mending seam a don't can of the ching and sugher beations the made
# And she deed of the commetis sters the prust trail and chunce the send and spitted to the pracem
# So wallie the money
# But the retic atalice in the parks which
# And I'm sunger toll off the batter back to see shicked it
# Someday set sacard fram burning out the mooden on the park to arm the poldars
# Saride a pack
# Brick be the wallest cormarinal tellettors of the sunclades
# To heart hand aronget soul the shand
# All I the warn throw while the rung onter patterics
# I strill a somether peace, shan staped the bot spared it brinks and tup it
# In’t this my chear a think to mad a barn on ole
# Asom a platies ast coldicter pilling alting
# Blew the but stellashed seatertalls that the frignterters
# String the cold at hand when the metiles and be the master trying the prease, I'm threadly water bulls in the pullate
# Tunter to through the fingers
# I'm hell a tallook simple or menith
# I crook in your pash and spil the pilling
# Boles and starvets triped in the face to beat the muddle
# I'm a seepin a can and low to bean the sarn and soldowing the self tenched of menstarts and to the cammit
# I'm a troubon trucker turned, so to breaked, shoulden and but they dreams on a blind off the brookent star
# Assal prodical well the mill burn
# I am a black case a tone on the pigs to the piggen britch
# Bicker a trunk and barn betoraming my cheaning
# And ship when a tence of a pilot polor to splock their fire
# The walk it of the but shit the bell breed
# I'm a searle see a clash the back wants to bring it world peal the paser starts bread in the manter
# I deal I see alk spother stard atanttom
# It's the same with and the pits and a this specially
# Stordy and the pr

# %% [markdown]
# ## Loading checkpoint

# %%
with open('rnn.net', 'rb') as f:
    checkpoint = torch.load(f)
    
loaded = CharRNN(checkpoint['tokens'], n_hidden=checkpoint['n_hidden'], n_layers=checkpoint['n_layers'])
loaded.load_state_dict(checkpoint['state_dict'])

# %%
print(sample(loaded, 2000, cuda=False, top_k=5, prime="New York"))
# Out:
# New York those back and a stan and spreading outsed my servess tellors and sticks and steres
# To beline the callioned speting
# It's left she to damake to hand his as out a marty tricks
# To my starting the pire of all spirit stalling that spete the muttle from but it's settle me wentert
# Till it blind the bleaded teets bell the potal to masters
# And the pation of the pathages
# We themearn's brooder spensing fuck the shook and well
# Aed a the blood on a shin off internives
# Attic alove the sprung common the batch in
# Aed the mother fung it's the beak for the motime
# Ster in the stop
# Anto they drug of the buck on a crom of the clunch
# Bathon a shank and traped bad a mine and spon a stink bottle pasting ousto the morting the produmes
# It's let the prin a purnen achuse my channies
# That's the see a stolar some and turn to pull it
# Low that hung a beak and head the bast
# And I'm an the beff stop
# And I'm a fing that walked then compoter
# And a still me a so day, and dank, the cat apop the same
# To the can to benew themered the contringed
# I wean I slipped a second incruded
# The midele spill that spenes and halk of the perstical
# Where your calling mind if sull shook out my life to be the mare to stepper that prace
# Thousand and he cromp through the mores
# At a stroke off with a ship drink to the bott messience all a polating as a proconame with a mett clettack then petalested, asser that
# Same shoved one the prodict
# I'm on a brick around stittle flaming assics
# Shark the she dish dignd my pingen pattening servilation seeps the bormach then crew or pouns
# When the cherich prodotics linerally coust
# Well anter the plessions whe presture chascar trade and stard to and me with monstor to the most born soulsten patered clean and she preader
# And I crail the spin a starked off the but betomene shill pig the bitter past the porment to see who ponsions
# I the strettors, arrow the chere to the belled of the past
# Somea to the canta drunken dectic tell to blessed if the clomp if to spark the blocks turn to that spearing
